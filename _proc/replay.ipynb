# %% [raw]
# ---
# description: Fill in a module description here
# output-file: replay.html
# title: Prioritized Experience Replay
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ### Prioritized Level Replay

# %%
#| echo: false
#| output: asis
show_doc(PrioritizedReplayDistribution)
# Out:
# ---
#
# [source](https://github.com/xrsrke/repaired/blob/main/repaired/replay.py#L16){target="_blank" style="float:right; font-size:smaller"}
#
# ### PrioritizedReplayDistribution
#
# >      PrioritizedReplayDistribution (rho:float=0.1, beta:float=0.1)
#
# Initialize self.  See help(type(self)) for accurate signature.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | rho | float | 0.1 |  |
# | beta | float | 0.1 | the beta coefficient for the P_S distribution |
# | **Returns** | **None** |  |  |
